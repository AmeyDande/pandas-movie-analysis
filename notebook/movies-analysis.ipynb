# %% [markdown]
# Importing necessary libriries

# %%
import pandas as pd 
import numpy as np 
import json
import ast

# %%
pd.options.display.max_columns = 30
df = pd.read_csv('../data/movies_metadata.csv')
df2 = pd.read_csv('../data/credits.csv')
df.head(10)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17448\1616237462.py:2: DtypeWarning: Columns (0: popularity) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# ...

# %%
df2 = pd.read_csv('../data/credits.csv')
df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %% [markdown]
# Now we are going to find out whats really going inside our DataFrame of movies_metadata
# it will help us to identify which type of data we have to really work with and we will perform operations accordingly

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  str
#  1   belongs_to_collection  4494 non-null   str
#  2   budget                 45466 non-null  str
#  3   genres                 45466 non-null  str
#  4   homepage               7782 non-null   str
#  5   id                     45466 non-null  str
#  6   imdb_id                45449 non-null  str
#  7   original_language      45455 non-null  str
#  8   original_title         45466 non-null  str
#  9   overview               44512 non-null  str
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  str
#  12  production_companies   45463 non-null  str
#  13  production_countries   45463 non-null  str
#  14  release_date           45379 non-null  str
# ...

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  str
#  1   crew    45476 non-null  str
#  2   id      45476 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 1.0 MB

# %% [markdown]
# Firstly, we are going to remove duplicate rows from the dataset before merging to avoid anomalies while performing further operations

# %%
df[df.duplicated(subset=['id'], keep=False)].sort_values(by='id')
# Out:
#        adult                              belongs_to_collection    budget  \
# 676    False                                                NaN         0
# 1465   False                                                NaN         0
# 44821  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...  16000000
# 4114   False  {'id': 34055, 'name': 'Pokémon Collection', 'p...  16000000
# 5710   False                                                NaN         0
# 20899  False                                                NaN         0
# 23534  False                                                NaN   3512454
# 4356   False                                                NaN   3512454
# 24844  False                                                NaN         0
# 14012  False                                                NaN         0
# 21165  False                                                NaN         0
# 19890  False                                                NaN         0
# ...

# %%
df = df.drop_duplicates(subset=['id'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45436 non-null  str
#  1   belongs_to_collection  4491 non-null   str
#  2   budget                 45436 non-null  str
#  3   genres                 45436 non-null  str
#  4   homepage               7777 non-null   str
#  5   id                     45436 non-null  str
#  6   imdb_id                45419 non-null  str
#  7   original_language      45425 non-null  str
#  8   original_title         45436 non-null  str
#  9   overview               44482 non-null  str
#  10  popularity             45431 non-null  object
#  11  poster_path            45050 non-null  str
#  12  production_companies   45433 non-null  str
#  13  production_countries   45433 non-null  str
#  14  release_date           45349 non-null  str
# ...

# %%
df2[df2.duplicated(subset=['id'], keep=False)].sort_values(by='id')
# Out:
#                                                     cast  \
# 25950  [{'cast_id': 12, 'character': 'The Creature', ...
# 25885  [{'cast_id': 12, 'character': 'The Creature', ...
# 5865   [{'cast_id': 15, 'character': 'Chuck Barris', ...
# 33838  [{'cast_id': 15, 'character': 'Chuck Barris', ...
# 9165   [{'cast_id': 11, 'character': 'Jef Costello', ...
# ...                                                  ...
# 25954  [{'cast_id': 7, 'character': 'Hollander', 'cre...
# 24163  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 45275  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 33196  [{'cast_id': 1, 'character': 'Jenjira', 'credi...
# 40051  [{'cast_id': 1, 'character': 'Jenjira', 'credi...
#
#                                                     crew      id
# 25950  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...    3057
# 25885  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...    3057
# 5865   [{'credit_id': '52fe43e2c3a36847f80760b5', 'de...    4912
# ...

# %%
df2 =df2.drop_duplicates(subset=['id'])

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45432 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45432 non-null  str
#  1   crew    45432 non-null  str
#  2   id      45432 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 1.4 MB

# %% [markdown]
# We droped the duplicate rows but we cant merge it yet cause, in our initial dataframe column 'id' is considered as string while in df2 column 'id' is in int64 format ,

# %% [markdown]
# Now we are going to convert strings to int64, float64, datetime64[us], respectively

# %% [markdown]
# firstly, we are going to drop the unwanted rows

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='str')

# %%
df = df.drop(columns=['adult', 'imdb_id','homepage','video','poster_path','original_title'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   str
#  1   budget                 45436 non-null  str
#  2   genres                 45436 non-null  str
#  3   id                     45436 non-null  str
#  4   original_language      45425 non-null  str
#  5   overview               44482 non-null  str
#  6   popularity             45431 non-null  object
#  7   production_companies   45433 non-null  str
#  8   production_countries   45433 non-null  str
#  9   release_date           45349 non-null  str
#  10  revenue                45430 non-null  float64
#  11  runtime                45173 non-null  float64
#  12  spoken_languages       45430 non-null  str
#  13  status                 45349 non-null  str
#  14  tagline                20401 non-null  str
# ...

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# Here, as we can see columns belongs_to_collection, genres, production_companies, production_countries, spoken_languages are in json format we nedd to convert it into python object, for that we will use json and ast

# %%
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df[['belongs_to_collection']].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
# dtypes: object(1)
# memory usage: 709.9+ KB

# %% [markdown]
# As we can see column belongs_to_collection is successfully converted from string to object
# Now, we are going to perform same operations on another columns

# %%
df['genres'] = df['genres'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df['production_companies'] = df['production_companies'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df['production_countries'] = df['production_countries'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df['spoken_languages'] = df['spoken_languages'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df[['belongs_to_collection','genres','production_companies','production_countries','spoken_languages']].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   genres                 45436 non-null  object
#  2   production_companies   45433 non-null  object
#  3   production_countries   45433 non-null  object
#  4   spoken_languages       45430 non-null  object
# dtypes: object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# As we can see all the json's are converted to pythen objects successfully

# %% [markdown]
# Now we are going to covert release_date from string to datetime64[ns]

# %% [markdown]
# And budget to

# %%
df[['release_date']].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   release_date  45349 non-null  str
# dtypes: str(1)
# memory usage: 709.9 KB

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors = 'coerce')

# %%
df[['release_date']].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   release_date  45346 non-null  datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 709.9 KB

# %% [markdown]
# Now we are going to convert python objects like budget, popularity  to numeric values

# %%
df['budget'] = pd.to_numeric(df['budget'], errors = 'coerce')

# %%
df['popularity'] = pd.to_numeric(df['popularity'], errors = 'coerce')

# %%
df[['budget','popularity']].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   budget      45433 non-null  float64
#  1   popularity  45430 non-null  float64
# dtypes: float64(2)
# memory usage: 1.0 MB

# %% [markdown]
# Now, its time to convert release_date to datetime64[us]

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors = 'coerce')

# %%
df['release_date'].info()
# Out:
# <class 'pandas.Series'>
# Index: 45436 entries, 0 to 45465
# Series name: release_date
# Non-Null Count  Dtype
# --------------  -----
# 45346 non-null  datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 709.9 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45436 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45433 non-null  float64
#  2   genres                 45436 non-null  object
#  3   id                     45436 non-null  str
#  4   original_language      45425 non-null  str
#  5   overview               44482 non-null  str
#  6   popularity             45430 non-null  float64
#  7   production_companies   45433 non-null  object
#  8   production_countries   45433 non-null  object
#  9   release_date           45346 non-null  datetime64[us]
#  10  revenue                45430 non-null  float64
#  11  runtime                45173 non-null  float64
#  12  spoken_languages       45430 non-null  object
#  13  status                 45349 non-null  str
#  14  tagline                20401 non-null  str
# ...

# %% [markdown]
# As we can see all the strings are converted to there respective Dtype as it should

# %% [markdown]
# Now, its time for df2

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45432 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45432 non-null  str
#  1   crew    45432 non-null  str
#  2   id      45432 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 1.4 MB

# %% [markdown]
# Again, Columns : cast and crew are in JSON format we need to convert into python objects

# %%
df2['cast'] = df2['cast'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df2['crew'] = df2['crew'].apply(lambda x:ast.literal_eval(x) if isinstance(x, str)else np.nan)

# %%
df2[['cast','crew']].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45432 entries, 0 to 45475
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45432 non-null  object
#  1   crew    45432 non-null  object
# dtypes: object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# Everything looks clear now in both the Dataframes

# %% [markdown]
# Now we are ready to fllater the lists of both the dataframes

# %%
df.loc[0, 'genres']
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df['genres'] = df['genres'].apply(lambda x: "|".join(i['name'] for i in x))

# %%
df.loc[0, 'genres']
# Out:
# 'Animation|Comedy|Family'

# %%
df.loc[0,'belongs_to_collection']
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df['belongs_to_collection'] = df['belongs_to_collection'].apply(lambda x: x['name'] if isinstance(x, dict) else np.nan)

# %%
df.loc[0,'belongs_to_collection']
# Out:
# 'Toy Story Collection'

# %%
df.loc[0,'spoken_languages']
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]

# %%
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.loc[0,'spoken_languages']
# Out:
# 'English'

# %%
df.loc[0,'production_companies']
# Out:
# [{'name': 'Pixar Animation Studios', 'id': 3}]

# %%
df['production_companies'] = df['production_companies'].apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.loc[0,'production_companies']
# Out:
# 'Pixar Animation Studios'

# %%
df.loc[0,'production_countries']
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]

# %%
df['production_countries'] = df['production_countries'].apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.loc[0,'production_countries']
# Out:
# 'United States of America'

# %% [markdown]
# We flattened the lists of dataframe1

# %% [markdown]
# Now, we will break df2 into 2 seperate columns cast and crew and perform further operations

# %%
df2.loc[0, 'cast']
# Out:
# [{'cast_id': 14,
#   'character': 'Woody (voice)',
#   'credit_id': '52fe4284c3a36847f8024f95',
#   'gender': 2,
#   'id': 31,
#   'name': 'Tom Hanks',
#   'order': 0,
#   'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'},
#  {'cast_id': 15,
#   'character': 'Buzz Lightyear (voice)',
#   'credit_id': '52fe4284c3a36847f8024f99',
#   'gender': 2,
#   'id': 12898,
#   'name': 'Tim Allen',
#   'order': 1,
#   'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'},
#  {'cast_id': 16,
#   'character': 'Mr. Potato Head (voice)',
#   'credit_id': '52fe4284c3a36847f8024f9d',
#   'gender': 2,
#   'id': 7167,
#   'name': 'Don Rickles',
#   'order': 2,
#   'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'},
#  {'cast_id': 17,
#   'character': 'Slinky Dog (voice)',
#   'credit_id': '52fe4284c3a36847f8024fa1',
#   'gender': 2,
#   'id': 12899,
#   'name': 'Jim Varney',
#   'order': 3,
#   'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'},
#  {'cast_id': 18,
#   'character': 'Rex (voice)',
# ...

# %%
cast = pd.DataFrame(df2['cast'])
crew = pd.DataFrame(df2['crew'])

# %%
cast
# Out:
#                                                     cast
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
# [45432 rows x 1 columns]

# %%
cast['cast_info'] = cast['cast'].apply(lambda x: "|".join(f"{i['character']} as {i['name']}" for i in x) if isinstance(x, list) else np.nan)

# %%
cast_info = cast['cast_info']

# %%
cast_info.iloc[0]
# Out:
# 'Woody (voice) as Tom Hanks|Buzz Lightyear (voice) as Tim Allen|Mr. Potato Head (voice) as Don Rickles|Slinky Dog (voice) as Jim Varney|Rex (voice) as Wallace Shawn|Hamm (voice) as John Ratzenberger|Bo Peep (voice) as Annie Potts|Andy (voice) as John Morris|Sid (voice) as Erik von Detten|Mrs. Davis (voice) as Laurie Metcalf|Sergeant (voice) as R. Lee Ermey|Hannah (voice) as Sarah Freeman|TV Announcer (voice) as Penn Jillette'

# %%
cast_info
# Out:
# 0        Woody (voice) as Tom Hanks|Buzz Lightyear (voi...
# 1        Alan Parrish as Robin Williams|Samuel Alan Par...
# 2        Max Goldman as Walter Matthau|John Gustafson a...
# 3        Savannah 'Vannah' Jackson as Whitney Houston|B...
# 4        George Banks as Steve Martin|Nina Banks as Dia...
#                                ...
# 45471     as Leila Hatami| as Kourosh Tahami| as Elham ...
# 45472    Sister Angela as Angel Aquino|Homer as Perry D...
# 45473    Emily Shaw as Erika Eleniak|Det. Mark Winston ...
# 45474     as Iwan Mosschuchin| as Nathalie Lissenko| as...
# 45475
# Name: cast_info, Length: 45432, dtype: str

# %% [markdown]
# Here, we attached Character and Name columns it will help us to identify which character is played by which actor
